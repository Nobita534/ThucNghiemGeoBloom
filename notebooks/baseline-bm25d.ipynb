# %%
# 1. Tải mã nguồn
# !git clone https://github.com/pkuliyi2015/GeoBloom.git
# %cd GeoBloom

# 2. Cài thư viện
# !pip install jieba_fast rank_bm25

# 3. Giải nén dữ liệu
# !apt-get update && apt-get install -y p7zip-full
# !cd data && 7z x GeoGLUE_clean.7z -y

# 4. Chạy thuật toán (Tối ưu 2 luồng để chống tràn RAM)
# !python baselines/BM25/BM25_D.py --dataset GeoGLUE_clean --threads 2
# Out:
# Cloning into 'GeoBloom'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 313 (delta 15), reused 20 (delta 6), pack-reused 276 (from 1)
# Receiving objects: 100% (313/313), 196.66 MiB | 38.04 MiB/s, done.
# Resolving deltas: 100% (145/145), done.
# /kaggle/working/GeoBloom
# Collecting jieba_fast
#   Downloading jieba_fast-0.53.tar.gz (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 54.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rank_bm25) (2.0.2)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Building wheels for collected packages: jieba_fast
#   Building wheel for jieba_fast (setup.py) ... done
#   Created wheel for jieba_fast: filename=jieba_fast-0.53-cp312-cp312-linux_x86_64.whl size=7659510 sha256=9c2a0856484dc80298899336c954bf9622804ac04bc8702e8cc09c6ca416e2cc
#   Stored in directory: /root/.cache/pip/wheels/65/67/37/8968a5b150cd26683fd229f2987694f1ff76c035f9ddc84bfe
# Successfully built jieba_fast
# Installing collected packages: jieba_fast, rank_bm25
# Successfully installed jieba_fast-0.53 rank_bm25-0.2.2
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,646 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [95.6 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.2 MB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,070 kB]
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,947 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [77.8 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,295 kB]
# Get:20 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,020 kB]
# Get:21 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.9 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,603 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,355 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [86.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,294 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.8 kB]
# Fetched 42.3 MB in 3s (13.7 MB/s)
#
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
#
#
# p7zip-full is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 225 not upgraded.
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,4 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 23029635 bytes (22 MiB)
#
# Extracting archive: GeoGLUE_clean.7z
# --
# Path = GeoGLUE_clean.7z
# Type = 7z
# Physical Size = 23029635
# Headers Size = 383
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 2
# Files: 11
# Size:       122573484
# Compressed: 23029635
# Loading query text: 100%|█████████████| 12157/12157 [00:00<00:00, 380183.07it/s]
# Splitting POI text:   0%|                            | 0/777295 [00:00<?, ?it/s]Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.637 seconds.
# Prefix dict has been built succesfully.
# Splitting POI text: 100%|████████████| 777295/777295 [00:57<00:00, 13445.21it/s]
# Processing queries: 100%|███████████████| 12157/12157 [4:53:52<00:00,  1.45s/it]
# 100%|████████████████████████████████████| 12157/12157 [00:16<00:00, 759.71it/s]

# %%
# !mkdir -p /kaggle/working/output_baselines
# !cp -r /kaggle/working/GeoBloom/data_bin/GeoGLUE_clean/ /kaggle/working/output_baselines/
# !find /kaggle/working/GeoBloom -mindepth 1 -maxdepth 1 ! -name 'result' -exec rm -rf {} +
